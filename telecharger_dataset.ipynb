# %%
import os

# Installation de l'outil Kaggle
os.system('pip install kaggle')

# Commande pour télécharger le dataset spécifique de l'atelier
os.system('kaggle datasets download -d andrewmvd/face-mask-detection')

# Dézipper automatiquement
import zipfile
with zipfile.ZipFile("face-mask-detection.zip","r") as zip_ref:
    zip_ref.extractall("dataset")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       9 # Dézipper automatiquement
#      10 import zipfile
# ---> 11 with zipfile.ZipFile("face-mask-detection.zip","r") as zip_ref:
#      12     zip_ref.extractall("dataset")
#
# File c:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'face-mask-detection.zip'
